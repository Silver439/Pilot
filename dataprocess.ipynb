# %%
import pandas as pd 
df1 = pd.read_csv('Data/worstcase/50_8_smallest.csv')
df2 = pd.read_csv('Data/worstcase/50_8_smallest_pre.csv')
df3 = pd.read_csv('Data/worstcase/50_8_cluster.csv')
df4 = pd.read_csv('Data/worstcase/50_8_cluster_pre.csv')
df5 = pd.read_csv('Data/worstcase/50_8_dynamic.csv')
df6 = pd.read_csv('Data/worstcase/50_8_dynamic_pre.csv')
df7 = pd.read_csv('Data/worstcase/50_8_cyclic.csv')
df8 = pd.read_csv('Data/worstcase/50_8_cyclic_pre.csv')
df1.iloc[:, 1:] = df1.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df2.iloc[:, 1:] = df2.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df3.iloc[:, 1:] = df3.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df4.iloc[:, 1:] = df4.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df5.iloc[:, 1:] = df5.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df6.iloc[:, 1:] = df6.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df7.iloc[:, 1:] = df7.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df8.iloc[:, 1:] = df8.iloc[:, 1:].applymap(lambda x: round(x + 0.128360, 6))
df1.to_csv('50_8_smallest.csv',index=False)
df2.to_csv('50_8_smallest_pre.csv',index=False)
df3.to_csv('50_8_cluster.csv',index=False)
df4.to_csv('50_8_cluster_pre.csv',index=False)
df5.to_csv('50_8_dynamic.csv',index=False)
df6.to_csv('50_8_dynamic_pre.csv',index=False)
df7.to_csv('50_8_cyclic.csv',index=False)
df8.to_csv('50_8_cyclic_pre.csv',index=False)
